# %%
# !echo $http_proxy

# %%
import comet_ml
import pandas as pd
import numpy as np
from sklearn.linear_model import SGDClassifier
from comet_ml import Experiment
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
df = pd.read_csv('diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
comet_ml.login()

# Display Comet UI

# %%
df.shape
# Out:
# (53940, 11)

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

def encode_labels(data):
    categories = (data.dtypes =="object")
    cat_cols = list(categories[categories].index)
    
    feature_label_encoder_dict = {}
    for col in cat_cols:
        feature_label_encoder_dict[col] = LabelEncoder()
        X[col] = feature_label_encoder_dict[col].fit_transform(X[col])

# %%
from sklearn.preprocessing import StandardScaler

def scale_numerical(data):
    scaler = StandardScaler()
    data[data.columns] = scaler.fit_transform(data[data.columns])

# %%
def set_target(x):
    golden_set = ['Ideal', 'Premium', 'Very Good']
    if x in golden_set:
        return 'Gold'
    return 'Silver'
df['target'] = df['cut'].apply(lambda x: set_target(x))
df.drop("cut", axis = 1,inplace=True)

# %%
X = df.drop("target", axis = 1)
y = df["target"]

# %%
encode_labels(X)
scale_numerical(X)

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

def compute_metrics(y_pred, y_true):
    metrics = {}
    metrics['precision'] = precision_score(y_true, y_pred)
    metrics['recall'] = recall_score(y_true, y_pred)
    metrics['f1-score'] = f1_score(y_true, y_pred)
    metrics['accuracy'] =  accuracy_score(y_true, y_pred)
    return metrics

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
import pickle

def run_experiment(ModelClass, name):
    experiment = Experiment(project_name="Datascience")
    experiment.set_name(name)
    experiment.add_tag(name)
    
    model = ModelClass()
    with experiment.train():    
        model.fit(X_train, y_train)
        y_pred = model.predict(X_train)
        metrics = compute_metrics(y_pred, y_train)
        experiment.log_metrics(metrics)
        experiment.log_confusion_matrix(y_train, y_pred, title = "Train Confusion Matrix", file_name="train_confusion_matrix.json")
        
    
    with experiment.validate():
        y_pred = model.predict(X_test)
        metrics = compute_metrics(y_pred, y_test)
        experiment.log_metrics(metrics)
        experiment.log_confusion_matrix(y_test, y_pred, title = "validate Confusion Matrix", file_name="validation_confusion_matrix.json")
        fpr, tpr, _ = roc_curve(y_test, y_pred)
        experiment.log_curve(name ,fpr, tpr)


    # plt.figure()
    # plt.plot(fpr, tpr, color='blue', label="ROC Curve")
    # plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line for random classifier
    # plt.xlabel('False Positive Rate')
    # plt.ylabel('True Positive Rate')
    # plt.title('ROC Curve')
    # plt.legend(loc="lower right")
    # experiment.log_figure('ROC', plt)
        
    experiment.end()

# %%
run_experiment(RandomForestClassifier, 'RandomForest')
run_experiment(DecisionTreeClassifier, 'DecisionTreeClassifier')
run_experiment(GaussianNB, 'GaussianNB')
run_experiment(KNeighborsClassifier, 'KNeighborsClassifier')
run_experiment(SGDClassifier, 'SGD')
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/nast69/datascience/f4e06e3d431a4638a34541d815c2e593
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : RandomForest
# COMET INFO:     url                   : https://www.comet.com/nast69/datascience/f4e06e3d431a4638a34541d815c2e593
# COMET INFO:   Metrics:
# COMET INFO:     train_accuracy     : 0.9999768261030775
# COMET INFO:     train_f1-score     : 0.9999034096397179
# COMET INFO:     train_precision    : 1.0
# COMET INFO:     train_recall       : 0.9998068379370292
# COMET INFO:     validate_accuracy  : 0.9586577678902484
# COMET INFO:     validate_f1-score  : 0.8232963549920761
# COMET INFO:     validate_precision : 0.8767932489451477
# COMET INFO:     validate_recall    : 0.7759522031366691
# COMET INFO:   Others:
# COMET INFO:     Name : RandomForest
# COMET INFO:   Parameters:
# COMET INFO:     train_bootstrap                : True
# COMET INFO:     train_ccp_alpha                : 0.0
# COMET INFO:     train_class_weight             : None
# COMET INFO:     train_criterion                : gini
# COMET INFO:     train_max_depth                : None
# COMET INFO:     train_max_features             : sqrt
# COMET INFO:     train_max_leaf_nodes           : None
# COMET INFO:     train_max_samples              : None
# COMET INFO:     train_min_impurity_decrease    : 0.0
# COMET INFO:     train_min_samples_leaf         : 1
# COMET INFO:     train_min_samples_split        : 2
# COMET INFO:     train_min_weight_fraction_leaf : 0.0
# COMET INFO:     train_monotonic_cst            : None
# COMET INFO:     train_n_estimators             : 100
# COMET INFO:     train_n_jobs                   : None
# COMET INFO:     train_oob_score                : False
# COMET INFO:     train_random_state             : None
# COMET INFO:     train_verbose                  : 0
# COMET INFO:     train_warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     confusion-matrix         : 2
# COMET INFO:     curve                    : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (288.11 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/nast69/datascience/156231cfccba47e19d4749a51485c812
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : DecisionTreeClassifier
# COMET INFO:     url                   : https://www.comet.com/nast69/datascience/156231cfccba47e19d4749a51485c812
# COMET INFO:   Metrics:
# COMET INFO:     train_accuracy     : 1.0
# COMET INFO:     train_f1-score     : 1.0
# COMET INFO:     train_precision    : 1.0
# COMET INFO:     train_recall       : 1.0
# COMET INFO:     validate_accuracy  : 0.9441045606229144
# COMET INFO:     validate_f1-score  : 0.7740726863994005
# COMET INFO:     validate_precision : 0.7766917293233083
# COMET INFO:     validate_recall    : 0.7714712471994025
# COMET INFO:   Others:
# COMET INFO:     Name : DecisionTreeClassifier
# COMET INFO:   Parameters:
# COMET INFO:     train_ccp_alpha                : 0.0
# COMET INFO:     train_class_weight             : None
# COMET INFO:     train_criterion                : gini
# COMET INFO:     train_max_depth                : None
# COMET INFO:     train_max_features             : None
# COMET INFO:     train_max_leaf_nodes           : None
# COMET INFO:     train_min_impurity_decrease    : 0.0
# COMET INFO:     train_min_samples_leaf         : 1
# COMET INFO:     train_min_samples_split        : 2
# COMET INFO:     train_min_weight_fraction_leaf : 0.0
# COMET INFO:     train_monotonic_cst            : None
# COMET INFO:     train_random_state             : None
# COMET INFO:     train_splitter                 : best
# COMET INFO:   Uploads:
# COMET INFO:     confusion-matrix         : 2
# COMET INFO:     curve                    : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (288.11 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/nast69/datascience/637709fe558a45d49a5b100b1b66b70e
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : GaussianNB
# COMET INFO:     url                   : https://www.comet.com/nast69/datascience/637709fe558a45d49a5b100b1b66b70e
# COMET INFO:   Metrics:
# COMET INFO:     train_accuracy     : 0.9090192806822395
# COMET INFO:     train_f1-score     : 0.5608501118568233
# COMET INFO:     train_precision    : 0.6662237576401807
# COMET INFO:     train_recall       : 0.48425729186787714
# COMET INFO:     validate_accuracy  : 0.9049870226177233
# COMET INFO:     validate_f1-score  : 0.5572354211663066
# COMET INFO:     validate_precision : 0.6608606557377049
# COMET INFO:     validate_recall    : 0.4817027632561613
# COMET INFO:   Others:
# COMET INFO:     Name : GaussianNB
# COMET INFO:   Parameters:
# COMET INFO:     train_priors        : None
# COMET INFO:     train_var_smoothing : 1e-09
# COMET INFO:   Uploads:
# COMET INFO:     confusion-matrix         : 2
# COMET INFO:     curve                    : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (288.11 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/nast69/datascience/b35a0ef9f3784ed2b26bc3675af81f9a
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : KNeighborsClassifier
# COMET INFO:     url                   : https://www.comet.com/nast69/datascience/b35a0ef9f3784ed2b26bc3675af81f9a
# COMET INFO:   Metrics:
# COMET INFO:     train_accuracy     : 0.953744901742677
# COMET INFO:     train_f1-score     : 0.7832319721980886
# COMET INFO:     train_precision    : 0.8945671049367403
# COMET INFO:     train_recall       : 0.6965423990728221
# COMET INFO:     validate_accuracy  : 0.9299221357063404
# COMET INFO:     validate_f1-score  : 0.6752577319587629
# COMET INFO:     validate_precision : 0.7947421638018201
# COMET INFO:     validate_recall    : 0.5870052277819268
# COMET INFO:   Others:
# COMET INFO:     Name : KNeighborsClassifier
# COMET INFO:   Parameters:
# COMET INFO:     train_algorithm     : auto
# COMET INFO:     train_leaf_size     : 30
# COMET INFO:     train_metric        : minkowski
# COMET INFO:     train_metric_params : None
# COMET INFO:     train_n_jobs        : None
# COMET INFO:     train_n_neighbors   : 5
# COMET INFO:     train_p             : 2
# COMET INFO:     train_weights       : uniform
# COMET INFO:   Uploads:
# COMET INFO:     confusion-matrix         : 2
# COMET INFO:     curve                    : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (288.11 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/nast69/datascience/493b7b9b6dd945259e8a7ff78e9c66ba
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : SGD
# COMET INFO:     url                   : https://www.comet.com/nast69/datascience/493b7b9b6dd945259e8a7ff78e9c66ba
# COMET INFO:   Metrics:
# COMET INFO:     train_accuracy     : 0.8895532072673341
# COMET INFO:     train_f1-score     : 0.1480157311405077
# COMET INFO:     train_precision    : 0.9928057553956835
# COMET INFO:     train_recall       : 0.07996909406992467
# COMET INFO:     validate_accuracy  : 0.8862625139043382
# COMET INFO:     validate_f1-score  : 0.1578586135895676
# COMET INFO:     validate_precision : 0.9745762711864406
# COMET INFO:     validate_recall    : 0.08588498879761015
# COMET INFO:   Others:
# COMET INFO:     Name : SGD
# COMET INFO:   Parameters:
# COMET INFO:     train_alpha               : 0.0001
# COMET INFO:     train_average             : False
# COMET INFO:     train_class_weight        : None
# COMET INFO:     train_early_stopping      : False
# COMET INFO:     train_epsilon             : 0.1
# COMET INFO:     train_eta0                : 0.0
# COMET INFO:     train_fit_intercept       : True
# COMET INFO:     train_l1_ratio            : 0.15
# COMET INFO:     train_learning_rate       : optimal
# COMET INFO:     train_loss                : hinge
# COMET INFO:     train_max_iter            : 1000
# COMET INFO:     train_n_iter_no_change    : 5
# COMET INFO:     train_n_jobs              : None
# COMET INFO:     train_penalty             : l2
# COMET INFO:     train_power_t             : 0.5
# COMET INFO:     train_random_state        : None
# COMET INFO:     train_shuffle             : True
# COMET INFO:     train_tol                 : 0.001
# COMET INFO:     train_validation_fraction : 0.1
# COMET INFO:     train_verbose             : 0
# COMET INFO:     train_warm_start          : False
# COMET INFO:   Uploads:
# COMET INFO:     confusion-matrix         : 2
# COMET INFO:     curve                    : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (288.11 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
